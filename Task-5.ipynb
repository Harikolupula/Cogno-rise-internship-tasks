# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\harik\Downloads\archive (3)\ds_salaries.csv")

# %%
df
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df.shape
# Out:
# (607, 10)

# %%
df.duplicated().sum()
# Out:
# 43

# %%
df.isna().sum()
# Out:
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.head()
# Out:
#   experience_level employment_type                   job_title  salary  \
# 0               MI              FT              Data Scientist   70000
# 1               SE              FT  Machine Learning Scientist  260000
# 2               SE              FT           Big Data Engineer   85000
# 3               MI              FT        Product Data Analyst   20000
# 4               SE              FT   Machine Learning Engineer  150000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             EUR          79833                 DE             0
# 1             USD         260000                 JP             0
# 2             GBP         109024                 GB            50
# 3             USD          20000                 HN             0
# 4             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# ...

# %%
df.tail()
# Out:
#     experience_level employment_type      job_title  salary salary_currency  \
# 602               SE              FT  Data Engineer  154000             USD
# 603               SE              FT  Data Engineer  126000             USD
# 604               SE              FT   Data Analyst  129000             USD
# 605               SE              FT   Data Analyst  150000             USD
# 606               MI              FT   AI Scientist  200000             USD
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 602         154000                 US           100               US
# 603         126000                 US           100               US
# 604         129000                 US             0               US
# 605         150000                 US           100               US
# 606         200000                 IN           100               US
#
#     company_size
# 602            M
# 603            M
# 604            M
# 605            M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   experience_level    607 non-null    object
#  1   employment_type     607 non-null    object
#  2   job_title           607 non-null    object
#  3   salary              607 non-null    int64
#  4   salary_currency     607 non-null    object
#  5   salary_in_usd       607 non-null    int64
#  6   employee_residence  607 non-null    object
#  7   remote_ratio        607 non-null    int64
#  8   company_location    607 non-null    object
#  9   company_size        607 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 47.5+ KB

# %%
df.describe()
# Out:
#              salary  salary_in_usd  remote_ratio
# count  6.070000e+02     607.000000     607.00000
# mean   3.240001e+05  112297.869852      70.92257
# std    1.544357e+06   70957.259411      40.70913
# min    4.000000e+03    2859.000000       0.00000
# 25%    7.000000e+04   62726.000000      50.00000
# 50%    1.150000e+05  101570.000000     100.00000
# 75%    1.650000e+05  150000.000000     100.00000
# max    3.040000e+07  600000.000000     100.00000

# %%
df.columns
# Out:
# Index(['experience_level', 'employment_type', 'job_title', 'salary',
#        'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.nunique()
# Out:
# experience_level        4
# employment_type         4
# job_title              50
# salary                272
# salary_currency        17
# salary_in_usd         369
# employee_residence     57
# remote_ratio            3
# company_location       50
# company_size            3
# dtype: int64

# %%
df
# Out:
#     experience_level employment_type                   job_title  salary  \
# 0                 MI              FT              Data Scientist   70000
# 1                 SE              FT  Machine Learning Scientist  260000
# 2                 SE              FT           Big Data Engineer   85000
# 3                 MI              FT        Product Data Analyst   20000
# 4                 SE              FT   Machine Learning Engineer  150000
# ..               ...             ...                         ...     ...
# 602               SE              FT               Data Engineer  154000
# 603               SE              FT               Data Engineer  126000
# 604               SE              FT                Data Analyst  129000
# 605               SE              FT                Data Analyst  150000
# 606               MI              FT                AI Scientist  200000
#
#     salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
plt.hist(df['salary'], bins=20, edgecolor='black')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Salary Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='job_title', y='salary', data=df, ci=None)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Job Title')
plt.ylabel('Average Salary')
plt.title('Average Salary by Job Title')
plt.show()
# Out:
# C:\Users\harik\AppData\Local\Temp\ipykernel_21632\2746850430.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='job_title', y='salary', data=df, ci=None)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='experience_level', y='salary', data=df, ci=None)
plt.xlabel('Experience Level')
plt.ylabel('Average Salary')
plt.title('Average Salary by Experience Level')
plt.show()
# Out:
# C:\Users\harik\AppData\Local\Temp\ipykernel_21632\4065164542.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='experience_level', y='salary', data=df, ci=None)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='employment_type', y='salary', data=df)
plt.xlabel('Empolyment type')
plt.ylabel('Salary')
plt.title('Salary Distribution by Education Level')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='experience_level', data=df)
plt.xlabel('Experience Level')
plt.ylabel('Count')
plt.title('Count of Each Experience Level')
plt.show()

# %%
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# C:\Users\harik\AppData\Local\Temp\ipykernel_21632\1669710827.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
